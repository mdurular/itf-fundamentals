# %%
text = input('Enter a text : ')
combine = ''
for i in text:
    if i not in combine:
        combine = combine + i
print(combine)
# Out:
# Enter a text : aaalllliiii
# ali

# %%
def split_and_join(line):
    return split_and_join(line)

# %%
a="this is a string".split()

# %%
for i in a:
    a="-".join(a)
print(a)
# Out:
# s--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
class Human: 

    def __init__(self, age = 0): 

        self._age = age 

    def get_age(self): 

        return self._age 

    def set_age(self, x): 

        self._age = x 

human1 = Human() 

human1.set_age(21) 

del human1

print(human1.get_age())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8697e1aa7c95> in <module>
#      19 del human1
#      20
# ---> 21 print(human1.get_age())
#
# NameError: name 'human1' is not defined

# %%
Cat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-fe7b2d0da580> in <module>
# ----> 1 Cat()
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %%
isinstance(dog4, Dog)
# Out:
# True
